# %%
# plots for GFP

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 3,figsize=(20, 5))

GFP = pd.read_csv('GFP.csv')

sns.lineplot(ax=axs[0],x='Time [ms]',y='l_soa_GFP',data=GFP,hue='Age',palette=['steelblue','orangered'],errorbar='se')
axs[0].set_title('VBM')
axs[0].set(ylabel='GFP [' + u'\u03bcV]')

sns.lineplot(ax=axs[1],x='Time [ms]',y='25_GFP',data=GFP,hue='Age',palette=['steelblue','orangered'],errorbar='se')
axs[1].set_title('CMot')
axs[1].set(ylabel='GFP [' + u'\u03bcV]')

sns.lineplot(ax=axs[2],x='Time [ms]',y='RT_GFP',data=GFP,hue='Age',palette=['steelblue','orangered'],errorbar='se')
axs[2].set_title('RT')
axs[1].set(ylabel='GFP [' + u'\u03bcV]')
# Out:
# [Text(0, 0.5, 'GFP [μV]')]

# %%
# plots for N1

fig, axs = plt.subplots(1, 3,figsize=(20, 5))

data = pd.read_csv('ERP_oneFeature.csv')
N1 = data[["Age","Subj","Time [ms]","l_soa_N1","25_N1","RT_N1"]]

axs[0].fill_between([100,300],1,-5.5,color='lightgray',alpha=0.5)
sns.lineplot(ax=axs[0],x='Time [ms]',y='l_soa_N1',data=N1,hue='Age',palette=['steelblue','orangered'],errorbar='se')

axs[1].fill_between([100,300],-3.5,4.2,color='lightgrey',alpha=0.5)
sns.lineplot(ax=axs[1],x='Time [ms]',y='25_N1',data=N1,hue='Age',palette=['steelblue','orangered'],errorbar='se')

axs[2].fill_between([100,300],-3.5,5,color='lightgrey',alpha=0.5)
sns.lineplot(ax=axs[2],x='Time [ms]',y='RT_N1',data=N1,hue='Age',palette=['steelblue','orangered'],errorbar='se')
# Out:
# <Axes: xlabel='Time [ms]', ylabel='RT_N1'>

# %%
# plots for N2

fig, axs = plt.subplots(1, 3,figsize=(20, 5))

N2 = data[["Age","Subj","Time [ms]","l_soa_N2","25_N2","RT_N2"]]

axs[0].fill_between([200,400],-1,2,color='lightgray',alpha=0.5)
sns.lineplot(ax=axs[0],x='Time [ms]',y='l_soa_N2',data=N2,hue='Age',palette=['steelblue','orangered'],errorbar='se')

axs[1].fill_between([200,400],-1.2,1.5,color='lightgray',alpha=0.5)
sns.lineplot(ax=axs[1],x='Time [ms]',y='25_N2',data=N2,hue='Age',palette=['steelblue','orangered'],errorbar='se')

axs[2].fill_between([200,400],-1.5,1,color='lightgray',alpha=0.5)
sns.lineplot(ax=axs[2],x='Time [ms]',y='RT_N2',data=N2,hue='Age',palette=['steelblue','orangered'],errorbar='se')
# Out:
# <Axes: xlabel='Time [ms]', ylabel='RT_N2'>

# %%
# plots for P3b

fig, axs = plt.subplots(1, 3,figsize=(20, 5))

P3b = data[["Age","Subj","Time [ms]","l_soa_P3b","25_P3b","RT_P3b"]]

axs[0].fill_between([300,700],-1.3,2.8,color='lightgray',alpha=0.5)
sns.lineplot(ax=axs[0],x='Time [ms]',y='l_soa_P3b',data=P3b,hue='Age',palette=['steelblue','orangered'],errorbar='se')

axs[1].fill_between([300,700],-1.4,1.8,color='lightgray',alpha=0.5)
sns.lineplot(ax=axs[1],x='Time [ms]',y='25_P3b',data=P3b,hue='Age',palette=['steelblue','orangered'],errorbar='se')

axs[2].fill_between([300,700],0,2.5,color='lightgray',alpha=0.5)
sns.lineplot(ax=axs[2],x='Time [ms]',y='RT_P3b',data=P3b,hue='Age',palette=['steelblue','orangered'],errorbar='se')
# Out:
# <Axes: xlabel='Time [ms]', ylabel='RT_P3b'>
